# %%
import pandas as pd
import glob
import os
import re 
print("Libraries imported successfully!")
# Out:
# Libraries imported successfully!

# %%
opendata = pd.read_excel('masterdbyear.xlsx')
opendata
# Out:
#                                    Name Of Item  Code  Sale QTY      Amt  \
# 0                                 BORA KHASKHAS   BK7       2.0   857.14
# 1                             CHITALE BAKARWADI   CB3       5.0   477.70
# 2      FAIR & LOVELY MENS GLOW & HANDSOME CREAM  FLM3       1.0   144.07
# 3                         GILL SHAVING CRM LIME  GSC2       2.0    66.10
# 4                       LIZOL DSC FLORAL CITRIC  LDF1       4.0   139.00
# ...                                         ...   ...       ...      ...
# 22831            TIDE JASMINE & ROSE POWDER 5KG  TJR3       1.0   483.05
# 22832                          TIDE+ J&R POWDER  TJP1      29.0   245.75
# 22833                                 WHEEL 4KG    W5      11.0  2330.46
# 22834                              WHEEL ACTIVE   WA1     168.0  9681.53
# 22835                    WOOSH DETERGENT POWDER  WDP1       1.0   356.78
#
#         Amt+GST  Closing ST  Month    Year
# 0        900.00         4.0    4.0  2024.0
# ...

# %%
opendata.to_csv('masterdbyear.csv', index=False)
